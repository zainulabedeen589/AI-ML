# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.pipeline import Pipeline

from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,accuracy_score

import joblib
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
n = 1500

# %%
area_sqft = np.random.normal(loc=900, scale=300, size=n).clip(300, 3000)
distance_km_to_metro = np.random.exponential(scale=3.0, size=n).clip(0.2, 20)
num_rooms = np.random.choice([1, 2, 3, 4], size=n, p=[0.25, 0.45, 0.25, 0.05])
building_age_years = np.random.normal(loc=12, scale=8, size=n).clip(0, 50)
noise = np.random.normal(0, 2500, size=n)
rent_inr = (
    25 * area_sqft
    - 1800 * distance_km_to_metro
    + 8000 * num_rooms
    - 120 * building_age_years
    + 9000 * np.exp(-distance_km_to_metro)   # nonlinear premium near metro
    + noise
).clip(8000, 200000)

# %%
df = pd.DataFrame({
    "area_sqft": area_sqft,
    "distance_km_to_metro": distance_km_to_metro,
    "num_rooms": num_rooms,
    "building_age_years": building_age_years,
    "rent_inr": rent_inr
})

# %%
df
# Out:
#         area_sqft  distance_km_to_metro  ...  building_age_years      rent_inr
# 0     1049.014246              0.943396  ...           13.144390  31126.887661
# 1      858.520710              5.229755  ...           18.796896  20397.105313
# 2     1094.306561              2.068994  ...           17.542861  44916.610745
# 3     1356.908957              0.240568  ...           16.660571  62970.313908
# 4      829.753988              0.200000  ...            5.600476  43337.515799
# ...           ...                   ...  ...                 ...           ...
# 1495  1501.827866             14.026507  ...           25.476199  24768.312426
# 1496  1518.451073              4.240752  ...           18.738379  60659.625682
# 1497  1262.509869              1.751769  ...           12.185568  42471.325417
# 1498  1207.218758              3.686816  ...           22.808126  33342.034202
# 1499  1077.758085              1.479107  ...            0.000000  46846.065965
#
# [1500 rows x 5 columns]

# %%
base_model = Pipeline(steps=[
    ('svr', SVR(kernel='linear', C=100.0, epsilon=0.1))
])

# %%
x = df.drop("rent_inr", axis=1)
y = df["rent_inr"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
base_model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('svr', SVR(C=100.0, kernel='linear'))])

# %%
base_model.predict(x_test)
# Out:
# array([48124.88878268, 43584.08122677, 33375.45590192, 43334.35731685,
#        41524.7987037 , 14835.43020935, 12058.38033933, 37944.27384505,
#        35813.41936804, 34741.92369321, 49933.77605641, 45402.46604519,
#        40385.88583119, 51552.32318512, 53328.70706914, 27063.41357037,
#        45628.35809571, 23225.69683758, 29231.80914126, 26043.80413975,
#        58725.331057  , 26491.43189223, 33229.99600607, 23048.05817676,
#        37073.66775219, 35729.59262864, 35360.19501469, 52126.6344711 ,
#        27364.65512323, 55243.7181545 , 41160.65740655, 46298.72370541,
#        30068.62919659, 36953.90333195, 56993.15381503, 37189.51812202,
#        55718.26511011, 35828.31590563,  7297.03304273, 40132.67129764,
#        22820.06472224, 37222.99292545, 16858.05698805, 17553.8656041 ,
#        28958.88851616, 26766.69956926, 40199.30191202, 27669.05628593,
#        33390.83343138, 20737.18554591, 34155.84632708, 41436.37481953,
# ...

# %%
r2_score(y_test, base_model.predict(x_test))
# Out:
# 0.9382535532165791

# %%
mean_absolute_error(y_test, base_model.predict(x_test))
# Out:
# 2408.541404344707

# %%
mean_squared_error(y_test, base_model.predict(x_test))
# Out:
# 9478540.509316081

# %%
.linear regression
.logistic regression
.svm
.svr

Try to create a machine learning suit where as a user they can pass any kind of data and your system must be able to 
feach data even from database sql , no sql , 

your system should give an option to select x and y columns
your system should be able to handle categorical and numerical data both

it should do a pre processing of the data like missing value treatment , scaling , encoding etc
it should select a set of models based on the problem statement regression or classification
and it should do hyperparameter tuning and give the best model based on accuracy or r2 score or any other metric
it should do a model comparision and give a best model and also a visual report to all of us in dashabrd and from next time 
onwards user can directly use the model by just passing the data and it should give the prediction

frontdn - streamlit , react next js
backend - python 
api - fastapi 
db = mongodb , neondb 

desing this system with proper user interface , logging , monitoring , error handling , modular code etc

for writing the prd - you can use claude 

for design you can use - ux pilot 

and for vibe coding - corsor and antigravity 

send me a deployed link whre i can pass my own data or i can connect with my own neuon db or mongodb and can get the model trained and can get the prediction
