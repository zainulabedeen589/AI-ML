# %%
a = 10

# %%
a
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
sudh = 234234

# %%
jeevan = 3453535

# %%
jeevan
# Out:
# 3453535

# %%
sudh
# Out:
# 234234

# %%
b = 34.5657

# %%
type(b)
# Out:
# float

# %%
c = "sudhanshu"

# %%
type(c)
# Out:
# str

# %%
d = 'sudh'

# %%
type(d)
# Out:
# str

# %%
e = """sudhanshu kumar"""

# %%
type(e)
# Out:
# str

# %%
f = "sudh's"

# %%
f = 'sudh"s'

# %%
e = """sudhanshu kumar"""

# %%
a = """my 
name 
is 
sudhanshu 
kumar"""

# %%
a
# Out:
# 'my \nname \nis \nsudhanshu \nkumar'

# %%
a = True

# %%
type(a)
# Out:
# bool

# %%
b = False

# %%
type(b)
# Out:
# bool

# %%
True - True
# Out:
# 0

# %%
True * False - True
# Out:
# -1

# %%
d = 6 + 8j

# %%
type(d)
# Out:
# complex

# %%
d.real
# Out:
# 6.0

# %%
d.imag
# Out:
# 8.0

# %%
d = 6 + 8j

# %% [markdown]
# int
# float
# str
# bool
# complex

# %%
l = [3,4,5,65,6,"sudh",345.67,435+7J,True]

# %%
type(l)
# Out:
# list

# %%
l = [3,4,5,65,6,"sudh",345.67,435+7J,True,[4,5,6,76],[4,5,6,7]]

# %%
t =(3,4,5,6,7,8,9,"sudh",345.67,435+7j,True)

# %%
type(t)
# Out:
# tuple

# %%
t=(2)

# %%
type(t)
# Out:
# int

# %%
s ={}

# %%
type(s)
# Out:
# dict

# %%
s ={4,5,6,7,8,9,4,5,6,7,8,9,"Sudh","sudh",True,False,345.67,345.67}

# %%
type(s)
# Out:
# set

# %%
s
# Out:
# {345.67, 4, 5, 6, 7, 8, 9, False, 'Sudh', True, 'sudh'}

# %%
d = {"name":"sudhanshu",
     "email":"sudhanshu@euron.one",
     "mobile":3453453453,
     "address":"my address is india"}

# %%
d1 = {
    "name":"sudhanshu", "name" : "sudh"
}

# %%
d1
# Out:
# {'name': 'sudh'}

# %%
d2 = {324535:"dfsdfs"}

# %%
d3 = {True:"fdsafasf"}

# %%
d4 = {345.567 :"frdfas"}

# %%
d5 = {"&&%&%" : "sasafafs"}

# %%
d6 = {[3,4,5,6]: "fsafasf"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 d6 = {[3,4,5,6]: "fsafasf"}
#
# TypeError: unhashable type: 'list'

# %%
d7 = {(3,4,5,6): "fsafasf"}

# %%
d8 = {{3,4,5,6}: "fsafasf"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 d8 = {{3,4,5,6}: "fsafasf"}
#
# TypeError: unhashable type: 'set'

# %%
d9 = {"name" :[324345,56,56,67,67,8]}

# %%
d9 = {"name" :(324345,56,56,67,67,8)}

# %%
d9 = {"name" :(324345,56,56,67,67,8),"address":{"city":"delhi","pincode":345345}}

# %%
d9
# Out:
# {'name': (324345, 56, 56, 67, 67, 8),
#  'address': {'city': 'delhi', 'pincode': 345345}}

# %%
list 
tuple
set
dictionary

# %%
s = "     sudha        nshu      "

# %%
len(s)
# Out:
# 28

# %%
l
# Out:
# [3, 4, 5, 65, 6, 'sudh', 345.67, (435+7j), True, [4, 5, 6, 76], [4, 5, 6, 7]]

# %%
len(l)
# Out:
# 11

# %%
t = (3,4,5,65,6,"sudh",345.67,435+7J,True)

# %%
len(t)
# Out:
# 9

# %%
s= "sudhanshu"

# %%
s[0]
# Out:
# 's'

# %%
s[1]
# Out:
# 'u'

# %%
s[-8]
# Out:
# 'u'

# %%
s[-1]
# Out:
# 'u'

# %%
s[0:4]
# Out:
# 'sudh'

# %%
s[0:9:1]
# Out:
# 'sudhanshu'

# %%
s[0:9:2]
# Out:
# 'sdasu'

# %%
s[8:4:-1]
# Out:
# 'uhsn'

# %%
s[::-1]
# Out:
# 'uhsnahdus'

# %%
l = [3,4,5,65,6,"sudh",345.67,435+7J,True]

# %%
l[5][0:2]
# Out:
# 'su'

# %%
t = (3,4,5,65,6,"sudh",345.67,435+7J,True)

# %%
t[5]
# Out:
# 'sudh'

# %%
d= {"name":"sudhanshu",
     "email":"sudhanshu@euron.com"}

# %%
d['name']
# Out:
# 'sudhanshu'

# %%
d['email']
# Out:
# 'sudhanshu@euron.com'

# %%
s={4,5,6,7,7,78}

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s = "my name is sudhanshu kumar"

# %%
s = "kalpesh"

# %%
s[::-1]
# Out:
# 'hseplak'
