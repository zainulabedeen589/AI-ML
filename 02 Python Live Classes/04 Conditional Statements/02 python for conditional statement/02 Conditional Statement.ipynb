# %%
a = 11 
if a % 2 == 0 :
    pass

# %%
10%3
# Out:
# 1

# %%
a % 2 == 0
# Out:
# False

# %%
a = int(input("Enter a number: "))
print(a)
if a % 2 == 0 :
    print("even")
else :
    print("odd")
# Out:
# 345
# odd

# %%
day = input("Enter a day: ").lower()
print(day)
if day == "sunday" or day == "saturday" :
    print("holiday")
else :
    print("working day")
# Out:
# 456hghnfsdhgghfsgsdgsdfgsdg gwgerg gd sdf gsdf
# working day

# %%
day = input("Enter a day: ").lower()
if day == "sunday" or day == "saturday" :
    print("holiday")
elif day in ["monday", "tuesday", "wednesday", "thursday", "friday"] :
    print("working day")
else :
    print("invalid day")
# Out:
# working day

# %%
l = [3,4,65,76,78]

# %%
3 in l
# Out:
# True

# %%
choice = int(input("Enter a choice: "))

if choice == 1 :
    print("you have selected pizza")
elif choice == 2 :
    print("you have selected burger")
elif choice == 3 :
    print("you have selected pasta")
elif choice == 4 :
    print("you have selected french fries")
else:
    print("invalid choice")
# Out:
# you have selected french fries

# %%
distance = int(input("Enter distance in km: "))
if distance <= 5 :
    print("my fare will be 50  ")
elif distance <= 10 :
    print("my fare will be 100  ")
elif distance <= 15 :
    print("my fare will be 150  ")
elif distance <= 20 :
    print("my fare will be 200  ")
else :
    print("this is not a valid distance  ")
# Out:
# my fare will be 200

# %%
speed = int(input("Enter speed in km/hr: "))
single = input("is it a single trip (yes/no): ").lower()
if speed <=60:
    if single == "yes":
        print("i should stop my vehicle")
    else:
        print("i can continue my journey")
elif speed <=80:
    print("you have already voilated the speed limit")
# Out:
# you have already voilated the speed limit

# %%
occupation = input("Enter your occupation: ").lower()
price = int(input("enter the price of laptop"))
print(occupation , price)
if occupation == "student":
    if price >10000:
        print("i will give you 15% of dicount")
    else:
        print("i will give you 5% of dicount")
elif occupation == "employee":
    if price >10000:
        print("i will give you 10% of dicount")
    else:
        print("i will give you 3% of dicount")
else :
    if price >10000:
        print("i will give you 5% of dicount")
    else:
        print("i will give you 2% of dicount")
# Out:
# dfasfdsafdfasdf 3543456
# i will give you 5% of dicount

# %%
b=input("enter a day")
print(b)
if b=="Sunday" or "Saturday":
    print("holiday")
else:
    print("its a working day")
# Out:
# Moknday
# holiday

# %%
b = "Moknday"
b=="Sunday" or "Saturday"
# Out:
# 'Saturday'

# %%
if "sdfsfs":
    print("test")
# Out:
# test

# %%
d = {'k1':"sudh", 'k2':"kumar", 'k3':"kumar"}

# %%
for i in d :
    print(i)
# Out:
# k1
# k2
# k3
