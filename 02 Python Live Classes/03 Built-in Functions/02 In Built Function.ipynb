# %%
s = "sudhanshu kumar"

# %%
s.capitalize()
# Out:
# 'Sudhanshu kumar'

# %%
s.title()
# Out:
# 'Sudhanshu Kumar'

# %%
s.count('su')
# Out:
# 1

# %%
s
# Out:
# 'sudhanshu kumar'

# %%
s.upper()
# Out:
# 'SUDHANSHU KUMAR'

# %%
s
# Out:
# 'sudhanshu kumar'

# %%
s
# Out:
# 'sudhanshu kumar'

# %%
s.center(40,'&')
# Out:
# '&&&&&&&&&&&&sudhanshu kumar&&&&&&&&&&&&&'

# %%
s.find('u')
# Out:
# 1

# %%
s.find('z')
# Out:
# -1

# %%
s.index('z')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 s.index('z')
#
# ValueError: substring not found

# %%
s.endswith('mar')
# Out:
# True

# %%
s.isalnum()
# Out:
# False

# %%
s
# Out:
# 'sudhanshu kumar'

# %%
s1 = "sudhanshuKumar123"

# %%
s1.isalnum()
# Out:
# True

# %%
s.isalpha()
# Out:
# False

# %%
s
# Out:
# 'sudhanshu kumar'

# %%
'sudh345646'.isdigit()
# Out:
# False

# %%
s.islower()
# Out:
# True

# %%
s.isupper()
# Out:
# False

# %%
s
# Out:
# 'sudhanshu kumar'

# %%
s.istitle()
# Out:
# False

# %%
l = [3,4,5,6,7,87,8,89,6,"sudhanshu",True ,5.6,6+7j,(3,4),{3,4,5},[3,4,5],None]

# %%
l.index(6)
# Out:
# 3

# %%
l.count(6)
# Out:
# 2

# %%
l.append(45)

# %%
l
# Out:
# [3,
#  4,
#  5,
#  6,
#  7,
#  87,
#  8,
#  89,
#  6,
#  'sudhanshu',
#  True,
#  5.6,
#  (6+7j),
#  (3, 4),
#  {3, 4, 5},
#  [3, 4, 5],
#  None,
#  45]

# %%
l.append([5,6,7,8])

# %%
l
# Out:
# [3,
#  4,
#  5,
#  6,
#  7,
#  87,
#  8,
#  89,
#  6,
#  'sudhanshu',
#  True,
#  5.6,
#  (6+7j),
#  (3, 4),
#  {3, 4, 5},
#  [3, 4, 5],
#  None,
#  45,
#  [5, 6, 7, 8]]

# %%
l.insert(2,"sudhanshu")

# %%
l
# Out:
# [3,
#  4,
#  'sudhanshu',
#  5,
#  6,
#  7,
#  87,
#  8,
#  89,
#  6,
#  'sudhanshu',
#  True,
#  5.6,
#  (6+7j),
#  (3, 4),
#  {3, 4, 5},
#  [3, 4, 5],
#  None,
#  45,
#  [5, 6, 7, 8]]

# %%
l.extend(23)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 l.extend(23)
#
# TypeError: 'int' object is not iterable

# %%
l.extend("sudh")

# %%
l
# Out:
# [3,
#  4,
#  'sudhanshu',
#  5,
#  6,
#  7,
#  87,
#  8,
#  89,
#  6,
#  'sudhanshu',
#  True,
#  5.6,
#  (6+7j),
#  (3, 4),
#  {3, 4, 5},
#  [3, 4, 5],
#  None,
#  45,
#  [5, 6, 7, 8],
#  's',
#  'u',
#  'd',
#  'h',
#  's',
#  'u',
#  'd',
#  'h']

# %%
l.extend([23,45,67])

# %%
l
# Out:
# [3,
#  4,
#  'sudhanshu',
#  5,
#  6,
#  7,
#  87,
#  8,
#  89,
#  6,
#  'sudhanshu',
#  True,
#  5.6,
#  (6+7j),
#  (3, 4),
#  {3, 4, 5},
#  [3, 4, 5],
#  None,
#  45,
#  [5, 6, 7, 8],
#  's',
#  'u',
#  'd',
#  'h',
#  's',
#  'u',
#  'd',
#  'h',
#  23,
#  45,
#  67]

# %%
l1 = [45,67,89]

# %%
l1.append(90)

# %%
l1
# Out:
# [45, 67, 89, 90]

# %%
l1.append([3,45,6])

# %%
l1
# Out:
# [45, 67, 89, 90, [3, 45, 6]]

# %%
l1.extend([4,5,6])

# %%
l1
# Out:
# [45, 67, 89, 90, [3, 45, 6], 4, 5, 6, 4, 5, 6]

# %%
l
# Out:
# [3,
#  4,
#  'sudhanshu',
#  5,
#  6,
#  7,
#  87,
#  8,
#  89,
#  6,
#  'sudhanshu',
#  True,
#  5.6,
#  (6+7j),
#  (3, 4),
#  {3, 4, 5},
#  [3, 4, 5],
#  None,
#  45,
#  [5, 6, 7, 8],
#  's',
#  'u',
#  'd',
#  'h',
#  's',
#  'u',
#  'd',
#  'h',
#  23,
#  45,
#  67]

# %%
l1
# Out:
# [45, 67, 89, 90, [3, 45, 6], 4, 5, 6, 4, 5, 6]

# %%
l1.pop()
# Out:
# 6

# %%
l1
# Out:
# [45, 67, 89, 90, [3, 45, 6], 4, 5, 6, 4, 5]

# %%
l1.pop(3)
# Out:
# 90

# %%
l1.pop(30)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 l1.pop(30)
#
# IndexError: pop index out of range

# %%
l1.remove(34)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 l1.remove(34)
#
# ValueError: list.remove(x): x not in list

# %%
l1.remove(89)

# %%
l1
# Out:
# [45, 67, [3, 45, 6], 4, 5, 6, 4, 5]

# %%
l1.remove(45)

# %%
l1
# Out:
# [67, [3, 45, 6], 4, 5, 6, 4, 5]

# %%
l1.remove(4)

# %%
l1
# Out:
# [67, [3, 45, 6], 5, 6, 4, 5]

# %%
l1
# Out:
# [67, [3, 45, 6], 5, 6, 4, 5]

# %%
l1.reverse()

# %%
l1
# Out:
# [5, 4, 6, 5, [3, 45, 6], 67]

# %%
l1 = l1[::-1]
# Out:
# [67, [3, 45, 6], 5, 6, 4, 5]

# %%
l1
# Out:
# [5, 4, 6, 5, [3, 45, 6], 67]

# %%
l1.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 l1.sort()
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
l2 = [3,4,5,6,7,8,9,1,2]

# %%
l2.sort()

# %%
l2
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
l = [4,5,6,7,8]
l1 = l

# %%
l2 = l.copy()

# %%
l[0] = "sudhanshu"

# %%
l1[0]
# Out:
# 4

# %%
l2[0]
# Out:
# 4

# %%
l
# Out:
# ['sudhanshu', 5, 6, 7, 8]

# %%
l1
# Out:
# ['sudhanshu', 5, 6, 7, 8]

# %%
l2
# Out:
# [4, 5, 6, 7, 8]

# %%
l
# Out:
# ['sudhanshu', 5, 6, 7, 8]

# %%
l.clear()

# %%
l
# Out:
# []

# %%
t = (3,4,5,6,7,8,9,1,2)

# %%
t.index(5)
# Out:
# 2

# %%
t.count(5)
# Out:
# 1

# %%
s = {4,5,6,7,5,5,7,7,8,9,9,6,6,87,8,8,8}

# %%
s
# Out:
# {4, 5, 6, 7, 8, 9, 87}

# %%
s.add(45)

# %%
s.add(4)

# %%
s
# Out:
# {4, 5, 6, 7, 8, 9, 45, 87}

# %%
t
# Out:
# (3, 4, 5, 6, 7, 8, 9, 1, 2)

# %%
t[0]
# Out:
# 3

# %%
t[0] = "sudh"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 t[0] = "sudh"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t = ("sudh",4,5,6,7,8,9,1,2)

# %%
t
# Out:
# ('sudh', 4, 5, 6, 7, 8, 9, 1, 2)

# %%
s = "sudhanshu kumar"

# %%
s[1]='z'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 s[1]='z'
#
# TypeError: 'str' object does not support item assignment

# %%
i = 345

# %%
s = {3,4,5,6,7,78,8,98,99,7,6,66,6}
s1 = {4,5,6,7,78}

# %%
s
# Out:
# {3, 4, 5, 6, 7, 8, 66, 78, 98, 99}

# %%
s1
# Out:
# {4, 5, 6, 7, 78}

# %%
s.difference(s1)
# Out:
# {3, 8, 66, 98, 99}

# %%
s1.difference(s)
# Out:
# set()

# %%
d = {"name" :"sudhanshu" , "company":"euron" , "email":"sudhanshu@euron.one" , "subjenct":["python","web dev","data science"]}

# %%
d
# Out:
# {'name': 'sudhanshu',
#  'company': 'euron',
#  'email': 'sudhanshu@euron.one',
#  'subjenct': ['python', 'web dev', 'data science']}

# %%
list(d.items())[0][0]
# Out:
# 'name'

# %%
d.keys()
# Out:
# dict_keys(['name', 'company', 'email', 'subjenct'])

# %%
d.values()
# Out:
# dict_values(['sudhanshu', 'euron', 'sudhanshu@euron.one', ['python', 'web dev', 'data science']])

# %%
d.pop('name')
# Out:
# 'sudhanshu'

# %%
d
# Out:
# {'company': 'euron',
#  'email': 'sudhanshu@euron.one',
#  'subjenct': ['python', 'web dev', 'data science']}

# %%
d.popitem()
# Out:
# ('subjenct', ['python', 'web dev', 'data science'])

# %%
d
# Out:
# {'company': 'euron', 'email': 'sudhanshu@euron.one'}

# %%
d.update({"comapny":"euron1"})

# %%
d
# Out:
# {'company': 'euron', 'email': 'sudhanshu@euron.one', 'comapny': 'euron1'}
