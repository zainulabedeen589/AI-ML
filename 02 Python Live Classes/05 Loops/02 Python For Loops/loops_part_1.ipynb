# %%
x = 5
y = 5

# %%
id(x)
# Out:
# 140704283939752

# %%
id(y)
# Out:
# 140704283939752

# %%
a = "sudh"
b = "sudh"

# %%
id(a)
# Out:
# 2665997480304

# %%
id(b)
# Out:
# 2665997480304

# %%
l = [4,5,6]
l1  = [4,5,6]

# %%
id(l)
# Out:
# 2665997718464

# %%
id(l1)
# Out:
# 2665997272704

# %%
c = 345356345
d = 345356345

# %%
id(c)
# Out:
# 2665998891984

# %%
id(d)
# Out:
# 2665998884560

# %%
l = [1,2,3,4,5]
l[0]
# Out:
# 1

# %%
l[1]
# Out:
# 2

# %%
l[4]
# Out:
# 5

# %%
l[40]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 l[40]
#
# IndexError: list index out of range

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
for sudh in l :
    print(sudh * 4)
# Out:
# 4
# 8
# 12
# 16
# 20

# %%
l = [4,5,6,8,98,9,"sudh",345.56,True]

# %%
for i in l:
    if type(i) == int:
        print(i)
# Out:
# 4
# 5
# 6
# 8
# 98
# 9

# %%
for i in l:
    print(int(i))
# Out:
# 4
# 5
# 6
# 8
# 98
# 9
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 for i in l:
# ----> 2     print(int(i))
#
# ValueError: invalid literal for int() with base 10: 'sudh'

# %%
int("sudh")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 int("sudh")
#
# ValueError: invalid literal for int() with base 10: 'sudh'

# %%
l
# Out:
# [4, 5, 6, 8, 98, 9, 'sudh', 345.56, True]

# %%
l1 = []
for i in l:
    if type(i) == int:
        l1.append(i)
print(l1)
# Out:
# [4, 5, 6, 8, 98, 9]

# %%
l1
# Out:
# [4, 5, 6, 8, 98, 9]

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
list(range(1,5))
# Out:
# [1, 2, 3, 4]

# %%
list(range(1,5,2))
# Out:
# [1, 3]

# %%
l = [54,6,7,8,9,90,0,"sudh",345,45.56,True,False,"kumar"]

# %%
l[0]
# Out:
# 54

# %%
l[2]
# Out:
# 7

# %%
l[4]
# Out:
# 9

# %%
l
# Out:
# [54, 6, 7, 8, 9, 90, 0, 'sudh', 345, 45.56, True, False, 'kumar']

# %%
list(range(0,len(l),2))
# Out:
# [0, 2, 4, 6, 8, 10, 12]

# %%
len(l)
# Out:
# 13

# %%
for i in range(0,len(l),2):
    print(l[i])
# Out:
# 54
# 7
# 9
# 0
# 345
# True
# kumar

# %%
l
# Out:
# [54, 6, 7, 8, 9, 90, 0, 'sudh', 345, 45.56, True, False, 'kumar']

# %%
for i in range(0,len(l)):
    if i%2!=0:
        print(l[i])
# Out:
# 6
# 8
# 90
# sudh
# 45.56
# False

# %%
list(range(len(l)-1,-1,-2))
# Out:
# [12, 10, 8, 6, 4, 2, 0]

# %%
for i in range(len(l)-1,-1,-2):
    print(l[i])
# Out:
# kumar
# True
# 345
# 0
# 9
# 7
# 54

# %%
t = (1,2,3,4,5)

for i in t :
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
s = {3,4,5,6,7,8,89,9,9,5,5,7,7,}

# %%
s
# Out:
# {3, 4, 5, 6, 7, 8, 9, 89}

# %%
for i in s :
    print(i)
# Out:
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 89

# %%
d = {'k1':"sudh", 'k2':"kumar", 'k3':"kumar"}
d['k1']
d.items()
d.keys()
d.values()
# Out:
# dict_values(['sudh', 'kumar', 'kumar'])

# %%
for i in d.keys():
    print(d[i])
# Out:
# sudh
# kumar
# kumar

# %%
d.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3'])
