# %%
t = ()
type(t)
# Out:
# tuple

# %%
t = (3,4,5,6,7,87,45.56,"euro","sudh",345+56j,True)

# %%
t
# Out:
# (3, 4, 5, 6, 7, 87, 45.56, 'euro', 'sudh', (345+56j), True)

# %%
t[0]
# Out:
# 3

# %%
t[2:8]
# Out:
# (5, 6, 7, 87, 45.56, 'euro')

# %%
t[0] = "sudh"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 t[0] = "sudh"
#
# TypeError: 'tuple' object does not support item assignment

# %%
l = [4,5,6]
t1 = (2,3,4)

# %%
l[0]
# Out:
# 4

# %%
l[0] = "euron"

# %%
t1[0]
# Out:
# 2

# %%
t1[0] = "euron"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 t1[0] = "euron"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t
# Out:
# (3, 4, 5, 6, 7, 87, 45.56, 'euro', 'sudh', (345+56j), True)

# %%
for i in t:
    print(i)
# Out:
# 3
# 4
# 5
# 6
# 7
# 87
# 45.56
# euro
# sudh
# (345+56j)
# True

# %%
for i in t :
    if type(i) == int :
        print(i)
# Out:
# 3
# 4
# 5
# 6
# 7
# 87

# %%
a = 1
b=2
c =3

# %%
t = 1,2,3

# %%
a,b,c = t

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3

# %%
t
# Out:
# (1, 2, 3)

# %%
t.count(1)
# Out:
# 1

# %%
t.index(2)
# Out:
# 1

# %%
t = (4,5,6,7,78,(4,5,6,7,7))

# %%
t[5][1]
# Out:
# 5

# %%
t = (4,5,6,7,78,(4,5,6,7,7),[3,4,5,6])

# %%
len(t)
# Out:
# 7
