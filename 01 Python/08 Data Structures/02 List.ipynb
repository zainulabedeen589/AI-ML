# %%
l = []

# %%
type(l)
# Out:
# list

# %%
l = [3,4,5,6,45.56,34+67j,True, "Sudh"]

# %%
l[0]
# Out:
# 3

# %%
l[-1]
# Out:
# 'Sudh'

# %%
l
# Out:
# [3, 4, 5, 6, 45.56, (34+67j), True, 'Sudh']

# %%
l[0:5]
# Out:
# [3, 4, 5, 6, 45.56]

# %%
l[0:8:2]
# Out:
# [3, 5, 45.56, True]

# %%
l[
    ::-1
]
# Out:
# ['Sudh', True, (34+67j), 45.56, 6, 5, 4, 3]

# %%
l
# Out:
# [3, 4, 5, 6, 45.56, (34+67j), True, 'Sudh']

# %%
for i in l :
    print(i)
# Out:
# 3
# 4
# 5
# 6
# 45.56
# (34+67j)
# True
# Sudh

# %%
for i in l :
    if type(i) == int and i >3 :
        print(i)
# Out:
# 4
# 5
# 6

# %%
l.append(56)

# %%
l
# Out:
# [3, 4, 5, 6, 45.56, (34+67j), True, 'Sudh', 56]

# %%
l.append("euron")

# %%
l
# Out:
# [3, 4, 5, 6, 45.56, (34+67j), True, 'Sudh', 56, 'euron']

# %%
l.insert(2,"sudh")

# %%
l
# Out:
# [3, 4, 'sudh', 5, 6, 45.56, (34+67j), True, 'Sudh', 56, 'euron']

# %%
l.insert(2,[4,5,6,7])

# %%
l
# Out:
# [3, 4, [4, 5, 6, 7], 'sudh', 5, 6, 45.56, (34+67j), True, 'Sudh', 56, 'euron']

# %%
l.extend(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 l.extend(4)
#
# TypeError: 'int' object is not iterable

# %%
l.extend("sudh")

# %%
l
# Out:
# [3,
#  4,
#  [4, 5, 6, 7],
#  'sudh',
#  5,
#  6,
#  45.56,
#  (34+67j),
#  True,
#  'Sudh',
#  56,
#  'euron',
#  's',
#  'u',
#  'd',
#  'h']

# %%
l.extend([4,5,6,7])

# %%
l
# Out:
# [3,
#  4,
#  [4, 5, 6, 7],
#  'sudh',
#  5,
#  6,
#  45.56,
#  (34+67j),
#  True,
#  'Sudh',
#  56,
#  'euron',
#  's',
#  'u',
#  'd',
#  'h',
#  4,
#  5,
#  6,
#  7]

# %%
l.pop()
# Out:
# 7

# %%
l.pop(2)
# Out:
# [4, 5, 6, 7]

# %%
l.pop(2)
# Out:
# 'sudh'

# %%
l
# Out:
# [3,
#  4,
#  5,
#  6,
#  45.56,
#  (34+67j),
#  True,
#  'Sudh',
#  56,
#  'euron',
#  's',
#  'u',
#  'd',
#  'h',
#  4,
#  5,
#  6]

# %%
l.pop(5)
# Out:
# (34+67j)

# %%
l
# Out:
# [3, 4, 5, 6, 45.56, True, 'Sudh', 56, 'euron', 's', 'u', 'd', 'h', 4, 5, 6]

# %%
l.pop(100)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 l.pop(100)
#
# IndexError: pop index out of range

# %%
l.remove(100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 l.remove(100)
#
# ValueError: list.remove(x): x not in list

# %%
l.remove(4)

# %%
l
# Out:
# [3, 5, 6, 45.56, True, 'Sudh', 56, 'euron', 's', 'u', 'd', 'h', 4, 5, 6]

# %%
l.count(5)
# Out:
# 2

# %%
l.index(5)
# Out:
# 1

# %%
l.index(500)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 l.index(500)
#
# ValueError: 500 is not in list

# %%
l
# Out:
# [3, 5, 6, 45.56, True, 'Sudh', 56, 'euron', 's', 'u', 'd', 'h', 4, 5, 6]

# %%
l1 = l

# %%
l = [1,2,3,4]
l1 = l

# %%
l[0] = "sudh"

# %%
l
# Out:
# ['sudh', 2, 3, 4]

# %%
l1
# Out:
# ['sudh', 2, 3, 4]

# %%
l2 = l.copy()

# %%
l[0] = 1234234

# %%
l
# Out:
# [1234234, 2, 3, 4]

# %%
l1
# Out:
# [1234234, 2, 3, 4]

# %%
l2
# Out:
# ['sudh', 2, 3, 4]

# %%
l.clear()

# %%
l
# Out:
# []
