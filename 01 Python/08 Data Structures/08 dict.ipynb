# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
d = {"name" : "sudhanshu"}

# %%
d
# Out:
# {'name': 'sudhanshu'}

# %%
d = {"name":"sudhaanshu","email_id" : "sudhanshu@euron.one" , "subject":["data science","big data","dsa"]}

# %%
d
# Out:
# {'name': 'sudhaanshu',
#  'email_id': 'sudhanshu@euron.one',
#  'subject': ['data science', 'big data', 'dsa']}

# %%
d1 = {23435 :"sudhanshu"}

# %%
d1 = {"dfsfd" :"sudhanshu"}

# %%
d1 = {(3,4,5,5) :"sudhanshu"}

# %%
d1 = {[4,5,6,7]:"sudhanshu"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 d1 = {[4,5,6,7]:"sudhanshu"}
#
# TypeError: unhashable type: 'list'

# %%
d1 = {{3,4,5,6,76} :"sudhanshu"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 d1 = {{3,4,5,6,76} :"sudhanshu"}
#
# TypeError: unhashable type: 'set'

# %%
d1 = {frozenset([4,5,6]):"sudhanshu"}

# %%
d1 = {#%%^ :"sudhanshu"}
# Out:
#   Cell In[14], line 1
#     d1 = {#%%^ :"sudhanshu"}
#                             ^
# SyntaxError: incomplete input

# %%
d1 = {"name":"sudh","name":"sudhanshu"}

# %%
d1
# Out:
# {'name': 'sudhanshu'}

# %%
d
# Out:
# {'name': 'sudhaanshu',
#  'email_id': 'sudhanshu@euron.one',
#  'subject': ['data science', 'big data', 'dsa']}

# %%
d[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 d[0]
#
# KeyError: 0

# %%
d
# Out:
# {'name': 'sudhaanshu',
#  'email_id': 'sudhanshu@euron.one',
#  'subject': ['data science', 'big data', 'dsa']}

# %%
d['name']
# Out:
# 'sudhaanshu'

# %%
d['email_id']
# Out:
# 'sudhanshu@euron.one'

# %%
d['subject']
# Out:
# ['data science', 'big data', 'dsa']

# %%
d
# Out:
# {'name': 'sudhaanshu',
#  'email_id': 'sudhanshu@euron.one',
#  'subject': ['data science', 'big data', 'dsa']}

# %%
d['phone_number'] = 345353535

# %%
d
# Out:
# {'name': 'sudhaanshu',
#  'email_id': 'sudhanshu@euron.one',
#  'subject': ['data science', 'big data', 'dsa'],
#  'phone_number': 345353535}

# %%
d['phone_number'] = 563475675754

# %%
d
# Out:
# {'name': 'sudhaanshu',
#  'email_id': 'sudhanshu@euron.one',
#  'subject': ['data science', 'big data', 'dsa'],
#  'phone_number': 563475675754}

# %%
d['info']= {'course':['ops',"dsa","system design"]}

# %%
d
# Out:
# {'name': 'sudhaanshu',
#  'email_id': 'sudhanshu@euron.one',
#  'subject': ['data science', 'big data', 'dsa'],
#  'phone_number': 563475675754,
#  'info': {'course': ['ops', 'dsa', 'system design']}}

# %%
d['info']['course'][1]
# Out:
# 'dsa'

# %%
d.keys()
# Out:
# dict_keys(['name', 'email_id', 'subject', 'phone_number', 'info'])

# %%
d.values()
# Out:
# dict_values(['sudhaanshu', 'sudhanshu@euron.one', ['data science', 'big data', 'dsa'], 563475675754, {'course': ['ops', 'dsa', 'system design']}])

# %%
d.items()
# Out:
# dict_items([('name', 'sudhaanshu'), ('email_id', 'sudhanshu@euron.one'), ('subject', ['data science', 'big data', 'dsa']), ('phone_number', 563475675754), ('info', {'course': ['ops', 'dsa', 'system design']})])

# %%
for i in d.keys():
    print(i)
# Out:
# name
# email_id
# subject
# phone_number
# info

# %%
d
# Out:
# {'name': 'sudhaanshu',
#  'email_id': 'sudhanshu@euron.one',
#  'subject': ['data science', 'big data', 'dsa'],
#  'phone_number': 563475675754,
#  'info': {'course': ['ops', 'dsa', 'system design']}}

# %%
for i in d.keys():
    print(d[i])
# Out:
# sudhaanshu
# sudhanshu@euron.one
# ['data science', 'big data', 'dsa']
# 563475675754
# {'course': ['ops', 'dsa', 'system design']}
