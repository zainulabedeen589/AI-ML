# %%
s = {}

# %%
type(s)
# Out:
# dict

# %%
s = {3}

# %%
type(s)
# Out:
# set

# %%
s = {2,3,4,5,6,7,32,2,5,6,7,8,98,5,5,5,6,7,"sudh" , "Sudh","sudh","Euron"}

# %%
s
# Out:
# {2, 3, 32, 4, 5, 6, 7, 8, 98, 'Euron', 'Sudh', 'sudh'}

# %%
s1 ={(4,5,6,7)}

# %%
s2= {[1,2,3,4]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 s2= {[1,2,3,4]}
#
# TypeError: unhashable type: 'list'

# %%
set([1,2,23,4,5,6,7,8,89,99,0])
# Out:
# {0, 1, 2, 4, 5, 6, 7, 8, 23, 89, 99}

# %%
set((3,3,4,5,6,7,878,2,32,34,5))
# Out:
# {2, 3, 4, 5, 6, 7, 32, 34, 878}

# %%
s
# Out:
# {2, 3, 32, 4, 5, 6, 7, 8, 98, 'Euron', 'Sudh', 'sudh'}

# %%
tuple(s)
# Out:
# (32, 'Euron', 2, 3, 4, 5, 6, 7, 8, 98, 'sudh', 'Sudh')

# %%
list(s)
# Out:
# [32, 'Euron', 2, 3, 4, 5, 6, 7, 8, 98, 'sudh', 'Sudh']

# %%
s
# Out:
# {2, 3, 32, 4, 5, 6, 7, 8, 98, 'Euron', 'Sudh', 'sudh'}

# %%
s.add(34)

# %%
s
# Out:
# {2, 3, 32, 34, 4, 5, 6, 7, 8, 98, 'Euron', 'Sudh', 'sudh'}

# %%
s1 = s.copy()

# %%
s.discard(34)

# %%
s
# Out:
# {2, 3, 32, 4, 5, 6, 7, 8, 98, 'Euron', 'Sudh', 'sudh'}

# %%
s.discard(3453465)

# %%
s.remove(6)

# %%
s.remove(3254345)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 s.remove(3254345)
#
# KeyError: 3254345

# %%
s1 = {3,4,5}
s2 = {1,2,3}

# %%
s1.difference(s2)
# Out:
# {4, 5}

# %%
s2.difference(s1)
# Out:
# {1, 2}

# %%
s1.intersection(s2)
# Out:
# {3}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5}

# %%
s1.pop()
# Out:
# 3

# %%
s1.clear()

# %%
s1
# Out:
# set()

# %%
s
# Out:
# {2, 3, 32, 4, 5, 7, 8, 98, 'Euron', 'Sudh', 'sudh'}

# %%
2 in s
# Out:
# True

# %%
3543245 in s
# Out:
# False

# %%
34 not in s
# Out:
# True

# %%
s
# Out:
# {2, 3, 32, 4, 5, 7, 8, 98, 'Euron', 'Sudh', 'sudh'}

# %%
s1 = {3,4,5,6,7}
s2 = {4,5,6}

# %%
s1.issubset(s2)
# Out:
# False

# %%
s2.issubset(s1)
# Out:
# True

# %%
f = frozenset([3,4,5,56,6,7,7,3,3,5,65,7])

# %%
f
# Out:
# frozenset({3, 4, 5, 6, 7, 56, 65})

# %%
type(f)
# Out:
# frozenset

# %%
f
# Out:
# frozenset({3, 4, 5, 6, 7, 56, 65})
