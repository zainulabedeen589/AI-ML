# %%
list(enumerate("euron"))
# Out:
# [(0, 'e'), (1, 'u'), (2, 'r'), (3, 'o'), (4, 'n')]

# %%
for i in enumerate("euron"):
    print(i)
# Out:
# (0, 'e')
# (1, 'u')
# (2, 'r')
# (3, 'o')
# (4, 'n')

# %%
s = "euron"
for index , data  in enumerate(s):
    if index == 2 :
        print(s[2].upper())
    print(index,data)
# Out:
# 0 e
# 1 u
# R
# 2 r
# 3 o
# 4 n

# %%
l = [2,3,4,5,6]
l2 = [4,5,6]
l3 = ["sudh" , "kumar","euron"]

# %%
list(zip(l,l2,l3))
# Out:
# [(2, 4, 'sudh'), (3, 5, 'kumar'), (4, 6, 'euron')]

# %%
list(reversed("sudahnshu"))
# Out:
# ['u', 'h', 's', 'n', 'h', 'a', 'd', 'u', 's']

# %%
sorted([3,4,5,2,1,4,5,6],reverse=True)
# Out:
# [6, 5, 5, 4, 4, 3, 2, 1]

# %%
d = {"name":"sudhanshu" , "email_id":"sudhanshu@euron.one","class":["data","dsa"]}

# %%
for i in d.items():
    print(i)
# Out:
# ('name', 'sudhanshu')
# ('email_id', 'sudhanshu@euron.one')
# ('class', ['data', 'dsa'])
