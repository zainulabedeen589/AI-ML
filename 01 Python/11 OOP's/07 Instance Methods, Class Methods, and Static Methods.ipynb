# %%
class mentor:
    def __init__(self,name):
        self.name = name
        
    def introduction(self):
        return f"i am a mentor {self.name} on euron"

# %%
m = mentor("sudh")

# %%
m.introduction()
# Out:
# 'i am a mentor sudh on euron'

# %%
m1 = mentor("fdsafsafsaf")

# %%
m1.introduction()
# Out:
# 'i am a mentor fdsafsafsaf on euron'

# %%
class course:
    total_course = 0 
    
    def __init__(self,title):
        self.title= title
        course.total_course = course.total_course + 1 
    
    @classmethod
    def get_total_course(cls):
        return cls.total_course

# %%
co = course('sudhanshu kuamr')

# %%
co.title
# Out:
# 'sudhanshu kuamr'

# %%
co.total_course
# Out:
# 1

# %%
co1 = course("data scinece")

# %%
co1.total_course
# Out:
# 2

# %%
course.total_course
# Out:
# 2

# %%
co.get_total_course()
# Out:
# 2

# %%
course.get_total_course()
# Out:
# 2

# %%
class students:
    @staticmethod
    def is_valid_email(email):
        return "@" in email and "." in email

# %%
students.is_valid_email("sudhanshu@euron.one")
# Out:
# True
