# %%
class student:
    def __init__(self,name):
        self.name = name

# %%
s = student("sudh")

# %%
s.name
# Out:
# 'sudh'

# %%
class student:
    def __init__(self,name):
        self._name = name

# %%
s1 = student("sudh")

# %%
s1._name
# Out:
# 'sudh'

# %%
class student:
    def __init__(self,name):
        self.__name = name

# %%
s2 = student("sudh")

# %%
s2._student__name
# Out:
# 'sudh'

# %%
class student:
    def __init__(self,name):
        self.__name = name
        
    def get_name(self):
        return self.__name

# %%
s = student("sudh")

# %%
s.get_name()
# Out:
# 'sudh'
