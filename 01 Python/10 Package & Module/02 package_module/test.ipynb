# %%
import math

# %%
math.sqrt(456)
# Out:
# 21.354156504062622

# %%
math.pi
# Out:
# 3.141592653589793

# %%
import math as m

# %%
m.pi
# Out:
# 3.141592653589793

# %%
import numpy as np
import pandas as pd

# %%
import math

# %%
from math import sqrt,pi,log,pow

# %%
from math import *
