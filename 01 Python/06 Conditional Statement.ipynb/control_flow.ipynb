# %%
number = -10
if number > 0 :
    print("this number is a positive number")

# %%
number > 0
# Out:
# False

# %%
#CHECK EVEN AND ODD

number = int(input("enter the number"))
if number % 2 == 0 :
    print("number is even number",number)
else :
    print("number is odd" ,number)
# Out:
# number is odd 15

# %%
15 % 2 == 0
# Out:
# False

# %%
15 % 2
# Out:
# 1

# %%
score = int(input("input your score"))
if score >= 90 :
    print("Grade A")
elif score >= 80 :
    print("grade B ")
elif score >=70:
    print("Grade C")
elif score >=60:
    print("grade D ")
else :
    print("grade F" )
# Out:
# grade F

# %%
score = int(input("input your score"))
if score >= 90 :
    print("Grade A")
if score >= 80 :
    print("grade B ")
if score >=70:
    print("Grade C")
if score >=60:
    print("grade D ")
else :
    print("grade F" )
# Out:
# grade F

# %%
age = int(input("enter your age"))
citizenship = input("say yes or no about your citizenship")
if age > 18 and citizenship == 'yes':
    print("you are allowed for voting")
else:
    print("you are not allwoed for voting")
# Out:
# you are not allwoed for voting

# %%
income = int(input("enter your income"))
credit_score = int(input("enter your credit score"))
if income > 30000:
    if credit_score > 700:
        print("you will get loan")
    else:
        print("your credit score is too low but  your income is good")
else :
    print("income is too low")
# Out:
# your credit score is too low but  your income is good

# %%
gpa = 3.7
test_score = 85
extracuricular = "yes"

if gpa > 3.5 :
    if test_score > 90 :
        print("you will get a full scholorship")
    elif test_score > 80 :
        if extracuricular == 'yes':
            print("you will get a partial scholorship")
        else :
            print("you will get admission but not a scholorship ")
    else :
        print("still you have some chance to get admission")
elif gpa >3.0 :
    if test_score > 85:
        print("you will get a admisoin but no scholorship at all")     
    else :
        print("we will review your applicatoin and let you know about it ")  
        
else:
    print("no chance at all")
# Out:
# you will get a partial scholorship

# %%
number = 15 
"even" if number % 2 == 0 else "odd"
# Out:
# 'odd'

# %%
import datetime
current_hour=datetime.datetime.now().hour
print(current_hour)
"good morning" if current_hour < 12 else "good after noon" if current_hour < 18 else "good evening" if current_hour < 21 else "good night"
# Out:
# 21
# 'good night'

# %%
day = "monday"
match day :
    case "monday" :
        print("this is a fist day of week")
    case "tuesday":
        print("thsi is a second day of week")
    case "wednesday":
        print("this is a mid of week")
    case _ :
        print("its just an another day")
# Out:
# this is a fist day of week
