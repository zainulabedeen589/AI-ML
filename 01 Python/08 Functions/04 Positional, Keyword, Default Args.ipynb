# %%
def test(a,b):
    print(a)
    print(b)
    return a+b

# %%
test(23,45)
# Out:
# 23
# 45
# 68

# %%
test(b = 45,a = 23)
# Out:
# 23
# 45
# 68

# %%
def test2(a ,b,c,d = 10):
    return a,b,c,d

# %%
test2(2,3,5,50)
# Out:
# (2, 3, 5, 50)
