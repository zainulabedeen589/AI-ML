# %%
l = [3,4,45,56,7,7]

# %%
l1  = []
for i in l :
    if i % 2 == 0 :
        print(i)
        l1.append(i)
# Out:
# 4
# 56

# %%
l1
# Out:
# [4, 56]

# %%
len(l)
# Out:
# 6

# %%
type(l)
# Out:
# list

# %%
def test():
    print("this is my first function")

# %%
test()
# Out:
# this is my first function

# %%
test()
# Out:
# this is my first function

# %%
test()
# Out:
# this is my first function

# %%
a = test()
# Out:
# this is my first function

# %%
a + "sudh"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 a + "sudh"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
type(test())
# Out:
# this is my first function
# NoneType

# %%
def test1():
    return "thsi is my first fun"

# %%
test1()
# Out:
# 'thsi is my first fun'

# %%
type(test1())
# Out:
# str

# %%
test1() + "sudh"
# Out:
# 'thsi is my first funsudh'

# %%
a = test1()

# %%
a * 5
# Out:
# 'thsi is my first funthsi is my first funthsi is my first funthsi is my first funthsi is my first fun'

# %%
def test2():
    return "sudh" , 234, 34.56,[3,4,5,6]

# %%
for  i in test2() : 
    print(i)
# Out:
# sudh
# 234
# 34.56
# [3, 4, 5, 6]

# %%
a,b,c,d = test2()

# %%
a
# Out:
# 'sudh'

# %%
b
# Out:
# 234

# %%
c
# Out:
# 34.56

# %%
d
# Out:
# [3, 4, 5, 6]

# %%
def test5(a,b):
    return a+b

# %%
test5(45,3)
# Out:
# 48

# %%
def add(a,b):
    return a+b

# %%
add(56,45)
# Out:
# 101

# %%
def mul(a,b):
    return a*b

# %%
mul(5,6)
# Out:
# 30

# %%
def is_even(x ):
    return x %2 == 0

# %%
is_even(45)
# Out:
# False

# %%
is_even(34)
# Out:
# True

# %%
def pow(x,y):
    return x**y

# %%
pow(5,4)
# Out:
# 625

# %%
def even_list_filter(l:list) -> list:
    
    """
    this function will take inut as lsit and then it wil try 
    retrun you a list of even number created by sudhanshu
    """
    
    l1  = []
    for i in l :
        if i % 2 == 0 :
            print(i)
            l1.append(i)
    return l1

# %%
even_list_filter([4,5,6,6,87,8])
# Out:
# 4
# 6
# 6
# 8
# [4, 6, 6, 8]

# %%
print()
