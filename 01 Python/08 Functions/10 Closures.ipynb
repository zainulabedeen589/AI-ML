# %%
def outer():
    x = 10 
    def inner():
        print(x)
    return inner

# %%
closure = outer()

# %%
closure()
# Out:
# 10

# %%
closure
# Out:
# <function __main__.outer.<locals>.inner()>

# %%
def outer():
    x = 10 
    def inner():
        print(x)
    def inner1():
        print(x)
    def inner2():
        print(x)
    return inner ,inner1,inner2

# %%
closure = outer()

# %%
closure[0]()
# Out:
# 10

# %%
closure[1]()
# Out:
# 10

# %%
closure[2]()
# Out:
# 10

# %%
def counter():
    count = 0 
    def increament():
        nonlocal count
        count = count + 1
        return count
    return increament

# %%
c = counter()

# %%
c()
# Out:
# 1

# %%
c()
# Out:
# 2

# %%
c()
# Out:
# 3

# %%
def counter():
    count = 0 
    def increament():
        count = count + 1
        return count
    return increament

# %%
d = counter()
d()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[24], line 2
#       1 d = counter()
# ----> 2 d()
#
# Cell In[23], line 4, in counter.<locals>.increament()
#       3 def increament():
# ----> 4     count = count + 1
#       5     return count
#
# UnboundLocalError: cannot access local variable 'count' where it is not associated with a value

# %%
def power_of(n):
    def power(x):
        return x**n
    return power

# %%
square = power_of(2)
cube = power_of(3)
quard = power_of(4)

# %%
square(4)
# Out:
# 16

# %%
cube(5)
# Out:
# 125

# %%
quard(6)
# Out:
# 1296
