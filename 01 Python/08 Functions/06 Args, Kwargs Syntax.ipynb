# %%
def add(a,b):
    return a+b

# %%
add(3,4)
# Out:
# 7

# %%
def add(*sudh):
    return sudh

# %%
add()
# Out:
# ()

# %%
add(2)
# Out:
# (2,)

# %%
add(4,5,6,7)
# Out:
# (4, 5, 6, 7)

# %%
def add(*args):
    k = 0
    for i in args :
        k = k+ i
    return k

# %%
add()
# Out:
# 0

# %%
add(3,4,5,6)
# Out:
# 18

# %%
def multiply_all(number , *args):
    return number * args

# %%
multiply_all(5)
# Out:
# ()

# %%
multiply_all(2 , 5,6,7,8)
# Out:
# (5, 6, 7, 8, 5, 6, 7, 8)

# %%
(4,5,6,7) *3
# Out:
# (4, 5, 6, 7, 4, 5, 6, 7, 4, 5, 6, 7)

# %%
def profile(**kwargs):
    for i in kwargs.keys():
        print(i)
    return kwargs

# %%
profile(name = "sudhanshu" , email_id = "sudhanshu@euron.one" , phone_number = 2343424)
# Out:
# name
# email_id
# phone_number
# {'name': 'sudhanshu',
#  'email_id': 'sudhanshu@euron.one',
#  'phone_number': 2343424}

# %%
def profile(company , **kwargs):
    for i in kwargs.keys():
        print(i)
    return kwargs

# %%
profile("euron")
# Out:
# {}

# %%
def mix(*args,**kwargs):
    return args,kwargs

# %%
mix()
# Out:
# ((), {})

# %%
mix(23,34,54,56,6,name="sudh" , age = 32)
# Out:
# ((23, 34, 54, 56, 6), {'name': 'sudh', 'age': 32})

# %%
def mix(*sudh,**euron):
    return sudh,euron

# %%
mix(23,34,54,56,6,name="sudh" , age = 32)
# Out:
# ((23, 34, 54, 56, 6), {'name': 'sudh', 'age': 32})

# %%
def great(name):
    print(f"you are great {name}")

# %%
great("sudh")
# Out:
# you are great sudh

# %%
great(name = "sudh")
# Out:
# you are great sudh

# %%
def great1(name,/):
    print(f"you are great {name}")

# %%
great1("sudh")
# Out:
# you are great sudh

# %%
great1(name = "sudh")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 great1(name = "sudh")
#
# TypeError: great1() got some positional-only arguments passed as keyword arguments: 'name'

# %%
def great1(name,*,age,phonenumber):
    print(f"you are great {name},{age} , {phonenumber}")

# %%
great1(name = "sudh" , age = 32,phonenumber=345345)
# Out:
# you are great sudh,32 , 345345
