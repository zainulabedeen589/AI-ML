# %%
f = open('test1.txt','w')

# %%
f.write("my name is sudhanshu")
# Out:
# 20

# %%
f.close()

# %%
f = open('test1.txt')

# %%
f.read()
# Out:
# 'my name is sudhanshu'

# %%
f.close()

# %%
f = open('test1.txt','w')

# %%
f.write("i use to teach tech")
# Out:
# 19

# %%
f.close()

# %%
f = open('test1.txt','a')

# %%
f.write("\nadd this data afdetr the old data")
# Out:
# 34

# %%
f.close()

# %%
f= open('test1.txt','r')

# %%
f.read()
# Out:
# 'i use to teach tech\nadd this data afdetr the old data'

# %%
f= open('test1.txt','r')
for i in f :
    print(i.strip())
# Out:
# i use to teach tech
# add this data afdetr the old data

# %%
f= open('test1.txt','r')
f.read(10)
f.close()

# %%
l = ["first line\n" , "second line \n","third line \n"]

# %%
f = open("test2.txt",'w')
f.writelines(l)
f.close()

# %%
f = open("test2.txt",'r')
f.readlines()
# Out:
# ['first line\n', 'second line \n', 'third line \n']
