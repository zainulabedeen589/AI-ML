# %%
open('test1.txt','r+').read()
# Out:
# 'i use to teach tech\nadd this data afdetr the old data'

# %%
open('test4.txt','r+').read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 open('test4.txt','r+').read()
#
# File c:\Users\scl\anaconda3\envs\agentdemo\Lib\site-packages\IPython\core\interactiveshell.py:326, in _modified_open(file, *args, **kwargs)
#     319 if file in {0, 1, 2}:
#     320     raise ValueError(
#     321         f"IPython won't let you open fd={file} by default "
#     322         "as it is likely to crash IPython. If you know what you are doing, "
#     323         "you can use builtins' open."
#     324     )
# --> 326 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test4.txt'

# %%
f = open('test1.txt','r+')

# %%
f.read()
# Out:
# 'i use to teach tech\nadd this data afdetr the old data'

# %%
f.write("this is my read plus")
# Out:
# 20

# %%
f.close()

# %%
f = open('test1.txt','r+')

# %%
f.write("i am writing something into my test 1")
# Out:
# 37

# %%
f.close()

# %%
f = open('test1.txt','r+')

# %%
f.read()
# Out:
# 'i am writing something into my test 1detr the old datathis is my read plus'

# %%
f.write("this is my data whihc i am trynig to write")
# Out:
# 42

# %%
f.close()

# %%
f = open('test1.txt','r+')

# %%
f.seek(10)
# Out:
# 10

# %%
f.read()
# Out:
# 'ng something into my test 1detr the old datathis is my read plusthis is my data whihc i am trynig to write'

# %%
f.read()
# Out:
# ''

# %%
f.read()
# Out:
# ''

# %%
f.tell()
# Out:
# 116

# %%
f.close()

# %%
f = open('test1.txt','r+')

# %%
f.seek(10)
# Out:
# 10

# %%
f.tell()
# Out:
# 10

# %%
f = open('test6.txt','w+')

# %%
f.write("this is my another mode which is write plus mode")
# Out:
# 48

# %%
f.close()

# %%
f = open('test6.txt','a+')

# %%
f.read()
# Out:
# ''

# %%
f.tell()
# Out:
# 48

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'this is my another mode which is write plus mode'

# %%
f = open('test5.bin','wb')

# %%
f.write(b'\x00\x01\x02')
# Out:
# 3

# %%
f.close()

# %%
f = open('test5.bin','wb')

# %%
f.write(b'my name is sudhanshu kumar')
# Out:
# 26

# %%
f.close()

# %%
f = open('test5.bin','rb')

# %%
f.read()
# Out:
# b'\x00\x01\x02'
