# %%
f = open('test.txt','w')

# %%
f.write("this is my test file ")
# Out:
# 21

# %%
f.close()

# %%
with open('test.txt','w') as f :
    f.write("this is file context manager i am implementing")

# %%
with open('test.txt','r') as f :
    print(f.read(10))
# Out:
# this is fi
