# %%
import csv

# %%
with open('sample.csv','r') as f :
    print(f)
    print(csv.reader(f))
    reader = csv.reader(f)
    for i in reader:
        print(i)
# Out:
# <_io.TextIOWrapper name='sample.csv' mode='r' encoding='cp1252'>
# <_csv.reader object at 0x00000151399015A0>
# ['Name', 'Age', 'Country']
# ['Alice', '30', 'USA']
# ['Bob', '25', 'UK']
# ['Charlie', '35', 'Canada']

# %%
with open('sample.csv','r') as f :
    reader = csv.reader(f)
    next(reader)
    for i in reader:
        print(i)
# Out:
# ['Alice', '30', 'USA']
# ['Bob', '25', 'UK']
# ['Charlie', '35', 'Canada']

# %%
with open('output.csv','w') as f :
    writer = csv.writer(f)
    writer.writerow(['sudhanshu','kumar'])
    writer.writerows([['data scince' , 'big data'],['tech','non tech'],['python','javascript']])

# %%
with open('output.csv','r') as f :
    reader = csv.DictReader(f)
    for i in reader:
        print(i)
# Out:
# {'sudhanshu': 'data scince', 'kumar': 'big data'}
# {'sudhanshu': 'tech', 'kumar': 'non tech'}
# {'sudhanshu': 'python', 'kumar': 'javascript'}
