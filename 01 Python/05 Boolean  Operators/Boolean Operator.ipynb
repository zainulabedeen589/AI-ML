# %%
True
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
True * True
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
5 > 3
# Out:
# True

# %%
6 < 2
# Out:
# False

# %%
5 >= 7
# Out:
# False

# %%
5 >=3
# Out:
# True

# %%
5 <= 4
# Out:
# False

# %%
6 <=7
# Out:
# True

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
5 < 10 and 9 > 5
# Out:
# True

# %%
5== 5 and 10 > 5
# Out:
# True

# %%
# not > and > or

# %%
True  or False and False
# Out:
# True

# %%
(True or False) and False
# Out:
# False

# %%
not True or False
# Out:
# False

# %%
not False or False
# Out:
# True

# %%
True or False and not True
# Out:
# True

# %%
3+2 > 8
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
bool(0)
# Out:
# False

# %%
bool(456)
# Out:
# True

# %%
bool(-34)
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
bool("sudhanshu")
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool([4,5,6])
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
a = 5 
b = a

# %%
id(a)
# Out:
# 140710218613672

# %%
id(b)
# Out:
# 140710218613672

# %%
a is b
# Out:
# True

# %%
x = 9
y = 9

# %%
id(x)
# Out:
# 140710218613800

# %%
id(y)
# Out:
# 140710218613800

# %%
u = [4,5,6]
v = [4,5,6]

# %%
id(u)
# Out:
# 1809382595328

# %%
id(v)
# Out:
# 1809382389120

# %%
u is v
# Out:
# False

# %%
u is not v
# Out:
# True
